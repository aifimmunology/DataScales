# %%
import polars as pl

df = pl.read_parquet("gs://imm-zarr-poc/MegaZarr/MEGAZARR_dataset_obs/megazarr_cleaned.parquet")
# Out:
# /home/workspace/environment/minimalv4/lib/python3.11/site-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
base = "gs://imm-zarr-poc/sample_metadata/orginal_collective"
for k, out in [("specimens","specimens"), ("lab","lab"),
               ("survey","survey"), ("descriptors","descriptors")]:
    df = pl.read_csv(f"files/{k}.csv", infer_schema_length=10000)
    df.write_parquet(f"{base}/{out}.parquet")
    print("wrote", out, df.shape)
# Out:
# wrote specimens (311021, 17)
# wrote lab (2911, 403)
# wrote survey (10203, 8108)
# wrote descriptors (2911, 141)
